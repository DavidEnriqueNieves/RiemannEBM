# %%
import sys
sys.path.append("../")
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import math
from utils.toy_dataset import GaussianMixture
from torch.optim.lr_scheduler import CosineAnnealingLR

# %% [markdown]
# ## Parameter of the distribution

# %%
NB_GAUSSIANS = 200
RADIUS = 8
DEVICE = "cuda:1"
mean_ = (torch.linspace(0, 180, NB_GAUSSIANS + 1)[0:-1] * math.pi / 180)
MEAN = RADIUS * torch.stack([torch.cos(mean_), torch.sin(mean_)], dim=1)
COVAR = torch.tensor([[1., 0], [0, 1.]]).unsqueeze(0).repeat(len(MEAN), 1, 1)

x_p, y_p = torch.meshgrid(torch.linspace(-10, 10, 100), torch.linspace(-2.5, 10, 62), indexing='xy')
pos = torch.cat([x_p.flatten().unsqueeze(1), y_p.flatten().unsqueeze(1)], dim=1).to(DEVICE)

## Gaussian Mixture Uniformly distributed
weight_1 = (torch.ones(NB_GAUSSIANS) / NB_GAUSSIANS)
mixture_1 = GaussianMixture(center_data=MEAN, covar=COVAR, weight=weight_1).to(DEVICE)


fig, ax = plt.subplots(1, 3, figsize=(3*4, 4), dpi=100)
sample_1 = mixture_1.sample(1000).cpu().detach()
offset_1 = torch.tensor([0.0, 4.0])
mult_1  = torch.tensor([10.0, 6.0])

energy_landscape_1 = mixture_1.energy(pos)

sample_1_t = (sample_1-offset_1)/mult_1

mixture_sampling = GaussianMixture(center_data=MEAN, covar=COVAR*5, weight=weight_1).to(DEVICE)
ax[0].scatter(sample_1[:,0],sample_1[:,1])
ax[1].scatter(sample_1_t[:,0],sample_1_t[:,1])
im = ax[2].contourf(x_p, y_p, energy_landscape_1.view(62, 100).detach().cpu(), 20,
                        cmap='Blues_r',
                        alpha=0.8,
                        zorder=0,
                        levels=20)


plt.show()

## Gaussian Mixture non Uniformly distributed
linspace = torch.cat([torch.linspace(1, 30, 90),torch.ones(11)*30])
weight_2 = torch.cat([linspace, linspace[1:-1].flip(dims=(0,))])
weight_2 = weight_2/weight_2.sum()


linspace = torch.cat([torch.linspace(1, 30, 90),torch.ones(11)*30])



mixture_2 = GaussianMixture(center_data=MEAN, covar=COVAR, weight=weight_2).to(DEVICE)
energy_landscape_2 = mixture_2.energy(pos)

fig, ax = plt.subplots(1, 2, figsize=(2*4, 4), dpi=100)
sample_2 = mixture_2.sample(1000).cpu().detach()
mean_mix2 = sample_2.mean()
std_mix2 = sample_2.std()
ax[0].scatter(sample_2[:,0],sample_2[:,1])
im = ax[1].contourf(x_p, y_p, energy_landscape_2.view(62, 100).detach().cpu(), 20,
                        cmap='Blues_r',
                        alpha=0.8,
                        zorder=0,
                        levels=20)
plt.show()

# %%
# Out:
# tensor(2.5615) tensor(5.1351)

# %%
## Set the netowrk architecture
class MLP_ELU_convex(nn.Module):
    def __init__(self):
        super(MLP_ELU_convex, self).__init__()
        self.f = nn.Sequential(
            nn.Linear(2, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 32)
            )
        self.f1 = nn.Linear(32, 1)
        self.f2 = nn.Linear(32, 1)
        self.f3 = nn.Linear(32, 1)
    
    def forward(self, x):
        out_feat = self.f(x)
        energy = self.f1(out_feat)*self.f2(out_feat) + self.f3(out_feat**2)
        return energy

## sgld sampler 
def sgld(en, x_i, n_steps=20, sgld_lr=100, sgld_std=1e-2):
    x_s = x_i.clone()
    #x_s = 5*torch.randn_like(x) + torch.tensor([0, 5]).unsqueeze(0).to(x.device)
    x_s.requires_grad_(True)
    for i in range(n_steps):
        e = en(x_s)
        grad_x = torch.autograd.grad(
            outputs=e, 
            inputs=x_s,
            grad_outputs=torch.ones_like(e),  # same shape as f
            create_graph=True,
            retain_graph=True
            )[0]
        
        x_s.data = x_s.data - sgld_lr * grad_x + sgld_std * torch.randn_like(x_s)
    final_samples = x_s.detach()
    return final_samples

# %% [markdown]
# ## Train the EBM on the Uniformly distributed Gaussian mixture

# %%
## Network 
SGLD_STEPS = 100
SGLD_STD = 1e-2
SGLD_LR = 1e-2
EPOCH = 10000
BATCH_SIZE=128
netE = MLP_ELU_convex().to(DEVICE)
en = lambda x: netE(x) 

train_EBM=False
if train_EBM:
    optimizer = torch.optim.Adam(netE.parameters(), lr=1e-4)
        
    all_loss = []
    for i in range(EPOCH):
        optimizer.zero_grad()
        x = (mixture_1.sample(BATCH_SIZE) - mean_mix1)/std_mix1
        
        x_i = torch.randn_like(x)
        x_s = sgld(en, x_i, n_steps=SGLD_STEPS, sgld_std=SGLD_STD, sgld_lr=SGLD_LR)
        
        fp_all = en(x)
        fq_all = en(x_s)
        
        fp = fp_all.mean()
        fq = fq_all.mean()
        l_p_x = fp - fq
        
        
        loss = l_p_x
        loss.backward()
        optimizer.step()
        
        all_loss.append(loss.item())
        if i % 10 ==0 :
            print(f"{i} -- loss : {loss.item():0.6f}")
        if i % 2000 == 0 or i == EPOCH-1:
        
            x_i = torch.randn_like(x)
            x_s = sgld(en, x_i, n_steps=SGLD_STEPS, sgld_std=SGLD_STD, sgld_lr=SGLD_LR)
            all_e = en(pos*std_mix1+mean_mix1)
            fig, ax = plt.subplots(1, 3, figsize=(3*8,8))
            ax[0].plot(all_loss)
            ax[1].scatter(x_s[:,0].cpu().detach(), x_s[:,1].cpu().detach())
            im = ax[2].contourf(x_p, y_p, all_e.view(62,100).detach().cpu(), 20, cmap='Blues_r', alpha=0.8, zorder=0, levels=20)
            fig.colorbar(im, ax=ax[2])
            plt.show()
    to_save = {"weight": netE.state_dict(),
               "type": type(netE)}
    torch.save(to_save, f"./EBM_Uniform.pth")
else:
    ckpt = torch.load(f"./EBM_Uniform.pth", weights_only=False)
    netE.load_state_dict(ckpt["weight"], strict=True)
    x_i = torch.randn_like(x)
    x_s = sgld(en, x_i, n_steps=SGLD_STEPS, sgld_std=SGLD_STD, sgld_lr=SGLD_LR)
    x_p, y_p = torch.meshgrid(torch.linspace(-5, 5, 100), torch.linspace(-5, 5, 100), indexing='xy')
    pos = torch.cat([x_p.flatten().unsqueeze(1), y_p.flatten().unsqueeze(1)], dim=1).to(DEVICE)
    all_e = en(pos)
    fig, ax = plt.subplots(1, 2, figsize=(2*8,8))
    ax[0].scatter(x_s[:,0].cpu().detach(), x_s[:,1].cpu().detach())
    im = ax[1].contourf(x_p, y_p, all_e.view(100,100).detach().cpu(), 20, cmap='Blues_r', alpha=0.8, zorder=0, levels=20)
    fig.colorbar(im, ax=ax[1])
    plt.show()

# %%
## Train the EBM on the non Uniformly distributed Gaussian mixture

# %%
## Network 
SGLD_STEPS = 100
SGLD_STD = 1e-2
SGLD_LR = 1e-2
EPOCH = 10000
BATCH_SIZE=128
netE = MLP_ELU_convex().to(DEVICE)
en = lambda x: netE(x) 

train_EBM=True
if train_EBM:
    optimizer = torch.optim.Adam(netE.parameters(), lr=1e-4)
        
    all_loss = []
    for i in range(EPOCH):
        optimizer.zero_grad()
        x = (mixture_2.sample(BATCH_SIZE) - mean_mix2)/std_mix2
        
        x_i = torch.randn_like(x)
        x_s = sgld(en, x_i, n_steps=SGLD_STEPS, sgld_std=SGLD_STD, sgld_lr=SGLD_LR)
        
        fp_all = en(x)
        fq_all = en(x_s)
        
        fp = fp_all.mean()
        fq = fq_all.mean()
        l_p_x = fp - fq
        
        
        loss = l_p_x
        loss.backward()
        optimizer.step()
        
        all_loss.append(loss.item())
        if i % 10 ==0 :
            print(f"{i} -- loss : {loss.item():0.6f}")
        if i % 2000 == 0 or i == EPOCH-1:
        
            x_i = torch.randn_like(x)
            x_s = sgld(en, x_i, n_steps=SGLD_STEPS, sgld_std=SGLD_STD, sgld_lr=SGLD_LR)
            all_e = en(pos*std_mix1+mean_mix1)
            fig, ax = plt.subplots(1, 3, figsize=(3*8,8))
            ax[0].plot(all_loss)
            ax[1].scatter(x_s[:,0].cpu().detach(), x_s[:,1].cpu().detach())
            im = ax[2].contourf(x_p, y_p, all_e.view(62,100).detach().cpu(), 20, cmap='Blues_r', alpha=0.8, zorder=0, levels=20)
            fig.colorbar(im, ax=ax[2])
            plt.show()
    to_save = {"weight": netE.state_dict(),
               "type": type(netE)}
    torch.save(to_save, f"./EBM_non_Uniform.pth")
else:
    ckpt = torch.load(f"./EBM_non_Uniform.pth", weights_only=False)
    netE.load_state_dict(ckpt["weight"], strict=True)
    x_i = torch.randn_like(x)
    x_s = sgld(en, x_i, n_steps=SGLD_STEPS, sgld_std=SGLD_STD, sgld_lr=SGLD_LR)
    x_p, y_p = torch.meshgrid(torch.linspace(-5, 5, 100), torch.linspace(-5, 5, 100), indexing='xy')
    pos = torch.cat([x_p.flatten().unsqueeze(1), y_p.flatten().unsqueeze(1)], dim=1).to(DEVICE)
    all_e = en(pos)
    fig, ax = plt.subplots(1, 2, figsize=(2*8,8))
    ax[0].scatter(x_s[:,0].cpu().detach(), x_s[:,1].cpu().detach())
    im = ax[1].contourf(x_p, y_p, all_e.view(100,100).detach().cpu(), 20, cmap='Blues_r', alpha=0.8, zorder=0, levels=20)
    fig.colorbar(im, ax=ax[1])
    plt.show()
# Out:
# 0 -- loss : 0.000112
# 10 -- loss : -0.000013
# 20 -- loss : -0.000122
# 30 -- loss : -0.000223
# 40 -- loss : -0.000328
# 50 -- loss : -0.000589
# 60 -- loss : -0.001138
# 70 -- loss : -0.001544
# 80 -- loss : -0.002329
# 90 -- loss : -0.003306
# 100 -- loss : -0.005659
# 110 -- loss : -0.008224
# 120 -- loss : -0.014894
# 130 -- loss : -0.017181
# 140 -- loss : -0.029171
# 150 -- loss : -0.040105
# 160 -- loss : -0.058699
# 170 -- loss : -0.103159
# 180 -- loss : -0.130632
# 190 -- loss : -0.191951
# 200 -- loss : -0.238815
# 210 -- loss : -0.291905
# 220 -- loss : -0.032574
# 230 -- loss : -0.089666
# 240 -- loss : -0.303082
# 250 -- loss : 0.003055
# 260 -- loss : -0.255740
# 270 -- loss : 0.052189
# 280 -- loss : -0.244318
# 290 -- loss : -0.016066
# 300 -- loss : 0.026257
# 310 -- loss : -0.152313
# 320 -- loss : -0.115540
# 330 -- loss : 0.186150
# 340 -- loss : 0.051372
# 350 -- loss : -0.143081
# 360 -- loss : -0.121608
# 370 -- loss : 0.158135
# 380 -- loss : 0.038373
# 390 -- loss : -0.092074
# 400 -- loss : -0.172814
# 410 -- loss : -0.102093
# 420 -- loss : -0.139932
# 430 -- loss : -0.157676
# 440 -- loss : 0.000452
# 450 -- loss : -0.009034
# 460 -- loss : -0.094172
# 470 -- loss : 0.000003
# 480 -- loss : 0.190657
# 490 -- loss : 0.121685
# 500 -- loss : -0.074667
# 510 -- loss : -0.148071
# 520 -- loss : -0.009363
# 530 -- loss : 0.008511
# 540 -- loss : -0.091065
# 550 -- loss : -0.073832
# 560 -- loss : 0.008532
# 570 -- loss : 0.047044
# 580 -- loss : 0.176507
# 590 -- loss : -0.014940
# 600 -- loss : 0.123648
# 610 -- loss : -0.084307
# 620 -- loss : -0.098296
# 630 -- loss : -0.009096
# 640 -- loss : 0.141411
# 650 -- loss : -0.119046
# 660 -- loss : -0.186837
# 670 -- loss : -0.048311
# 680 -- loss : 0.136078
# 690 -- loss : 0.000616
# 700 -- loss : 0.023477
# 710 -- loss : 0.035136
# 720 -- loss : -0.131790
# 730 -- loss : -0.003591
# 740 -- loss : 0.199867
# 750 -- loss : 0.076984
# 760 -- loss : -0.112627
# 770 -- loss : 0.041155
# 780 -- loss : -0.129074
# 790 -- loss : -0.023734
# 800 -- loss : 0.205175
# 810 -- loss : 0.014585
# 820 -- loss : 0.137105
# 830 -- loss : 0.099081
# 840 -- loss : 0.023881
# 850 -- loss : 0.127068
# 860 -- loss : -0.278783
# 870 -- loss : -0.000789
# 880 -- loss : 0.011857
# 890 -- loss : -0.135699
# 900 -- loss : 0.007361
# 910 -- loss : 0.011031
# 920 -- loss : 0.168808
# 930 -- loss : 0.097588
# 940 -- loss : -0.156726
# 950 -- loss : 0.028414
# 960 -- loss : -0.156802
# 970 -- loss : -0.017217
# 980 -- loss : 0.042811
# 990 -- loss : -0.065681
# 1000 -- loss : -0.030691
# 1010 -- loss : -0.010810
# 1020 -- loss : 0.146545
# 1030 -- loss : 0.028522
# 1040 -- loss : 0.147217
# 1050 -- loss : -0.112981
# 1060 -- loss : -0.038107
# 1070 -- loss : -0.126411
# 1080 -- loss : -0.113196
# 1090 -- loss : -0.044389
# 1100 -- loss : -0.034801
# 1110 -- loss : -0.087870
# 1120 -- loss : 0.087388
# 1130 -- loss : -0.095714
# 1140 -- loss : -0.279388
# 1150 -- loss : 0.027085
# 1160 -- loss : 0.061020
# 1170 -- loss : -0.038825
# 1180 -- loss : -0.112280
# 1190 -- loss : 0.070215
# 1200 -- loss : 0.124595
# 1210 -- loss : -0.032360
# 1220 -- loss : -0.212031
# 1230 -- loss : 0.220867
# 1240 -- loss : 0.119039
# 1250 -- loss : 0.078969
# 1260 -- loss : -0.116865
# 1270 -- loss : 0.030759
# 1280 -- loss : 0.025315
# 1290 -- loss : -0.041766
# 1300 -- loss : -0.035584
# 1310 -- loss : 0.056876
# 1320 -- loss : -0.020185
# 1330 -- loss : 0.106865
# 1340 -- loss : 0.184889
# 1350 -- loss : -0.143536
# 1360 -- loss : -0.037558
# 1370 -- loss : -0.067439
# 1380 -- loss : 0.036028
# 1390 -- loss : -0.133383
# 1400 -- loss : -0.042174
# 1410 -- loss : -0.139717
# 1420 -- loss : -0.197587
# 1430 -- loss : 0.062896
# 1440 -- loss : -0.022434
# 1450 -- loss : 0.024742
# 1460 -- loss : 0.135047
# 1470 -- loss : -0.090245
# 1480 -- loss : 0.025169
# 1490 -- loss : -0.077590
# 1500 -- loss : 0.200639
# 1510 -- loss : 0.045801
# 1520 -- loss : -0.023983
# 1530 -- loss : -0.020072
# 1540 -- loss : 0.007192
# 1550 -- loss : -0.017300
# 1560 -- loss : -0.031089
# 1570 -- loss : -0.083574
# 1580 -- loss : -0.047060
# 1590 -- loss : -0.072065
# 1600 -- loss : 0.175067
# 1610 -- loss : 0.054621
# 1620 -- loss : -0.001916
# 1630 -- loss : -0.003971
# 1640 -- loss : 0.036220
# 1650 -- loss : -0.107413
# 1660 -- loss : 0.058074
# 1670 -- loss : -0.160268
# 1680 -- loss : -0.067129
# 1690 -- loss : -0.016652
# 1700 -- loss : -0.098905
# 1710 -- loss : 0.012335
# 1720 -- loss : 0.065629
# 1730 -- loss : 0.266363
# 1740 -- loss : 0.111248
# 1750 -- loss : 0.043046
# 1760 -- loss : -0.101090
# 1770 -- loss : 0.010128
# 1780 -- loss : -0.090575
# 1790 -- loss : -0.005185
# 1800 -- loss : -0.039412
# 1810 -- loss : -0.074417
# 1820 -- loss : -0.042000
# 1830 -- loss : -0.013098
# 1840 -- loss : -0.017175
# 1850 -- loss : 0.106079
# 1860 -- loss : -0.033591
# 1870 -- loss : 0.035057
# 1880 -- loss : -0.090301
# 1890 -- loss : 0.052972
# 1900 -- loss : 0.092937
# 1910 -- loss : 0.031513
# 1920 -- loss : -0.140605
# 1930 -- loss : 0.159134
# 1940 -- loss : -0.090193
# 1950 -- loss : 0.053189
# 1960 -- loss : 0.111965
# 1970 -- loss : 0.102499
# 1980 -- loss : 0.063092
# 1990 -- loss : -0.050263
# 2000 -- loss : -0.070292
# 2010 -- loss : 0.009928
# 2020 -- loss : 0.062439
# 2030 -- loss : 0.141033
# 2040 -- loss : 0.044652
# 2050 -- loss : -0.030622
# 2060 -- loss : -0.072090
# 2070 -- loss : -0.109103
# 2080 -- loss : -0.168925
# 2090 -- loss : -0.007215
# 2100 -- loss : -0.143401
# 2110 -- loss : -0.041276
# 2120 -- loss : -0.128053
# 2130 -- loss : 0.135599
# 2140 -- loss : -0.017676
# 2150 -- loss : -0.075635
# 2160 -- loss : -0.067739
# 2170 -- loss : 0.227990
# 2180 -- loss : 0.015395
# 2190 -- loss : -0.062602
# 2200 -- loss : 0.238385
# 2210 -- loss : 0.019234
# 2220 -- loss : -0.039706
# 2230 -- loss : -0.039077
# 2240 -- loss : -0.131979
# 2250 -- loss : 0.126551
# 2260 -- loss : 0.103034
# 2270 -- loss : -0.080340
# 2280 -- loss : 0.084403
# 2290 -- loss : 0.082281
# 2300 -- loss : 0.109468
# 2310 -- loss : 0.063327
# 2320 -- loss : -0.044134
# 2330 -- loss : 0.277551
# 2340 -- loss : -0.122224
# 2350 -- loss : -0.145522
# 2360 -- loss : 0.059690
# 2370 -- loss : 0.096011
# 2380 -- loss : -0.034109
# 2390 -- loss : 0.014627
# 2400 -- loss : -0.204087
# 2410 -- loss : -0.004479
# 2420 -- loss : -0.053965
# 2430 -- loss : -0.016163
# 2440 -- loss : 0.156775
# 2450 -- loss : 0.033238
# 2460 -- loss : -0.187290
# 2470 -- loss : -0.243467
# 2480 -- loss : -0.190641
# 2490 -- loss : 0.053728
# 2500 -- loss : 0.008311
# 2510 -- loss : 0.020409
# 2520 -- loss : 0.081164
# 2530 -- loss : -0.038544
# 2540 -- loss : -0.063153
# 2550 -- loss : 0.043523
# 2560 -- loss : -0.110083
# 2570 -- loss : -0.065203
# 2580 -- loss : 0.041796
# 2590 -- loss : 0.062530
# 2600 -- loss : 0.038030
# 2610 -- loss : -0.195472
# 2620 -- loss : 0.059193
# 2630 -- loss : -0.009130
# 2640 -- loss : -0.090065
# 2650 -- loss : 0.053556
# 2660 -- loss : -0.008879
# 2670 -- loss : -0.097574
# 2680 -- loss : 0.064807
# 2690 -- loss : 0.129371
# 2700 -- loss : 0.025012
# 2710 -- loss : -0.061732
# 2720 -- loss : -0.071028
# 2730 -- loss : -0.177476
# 2740 -- loss : -0.125402
# 2750 -- loss : 0.296780
# 2760 -- loss : 0.045371
# 2770 -- loss : 0.102821
# 2780 -- loss : 0.016398
# 2790 -- loss : 0.122270
# 2800 -- loss : 0.051376
# 2810 -- loss : 0.121009
# 2820 -- loss : 0.069108
# 2830 -- loss : -0.046410
# 2840 -- loss : 0.139439
# 2850 -- loss : -0.104918
# 2860 -- loss : -0.072334
# 2870 -- loss : -0.103850
# 2880 -- loss : -0.022903
# 2890 -- loss : 0.084023
# 2900 -- loss : -0.053030
# 2910 -- loss : -0.084703
# 2920 -- loss : 0.119487
# 2930 -- loss : 0.019021
# 2940 -- loss : -0.089488
# 2950 -- loss : 0.022651
# 2960 -- loss : 0.034719
# 2970 -- loss : -0.230863
# 2980 -- loss : 0.103125
# 2990 -- loss : 0.138878
# 3000 -- loss : 0.195630
# 3010 -- loss : 0.012712
# 3020 -- loss : -0.014160
# 3030 -- loss : -0.021668
# 3040 -- loss : -0.026111
# 3050 -- loss : 0.119415
# 3060 -- loss : -0.156316
# 3070 -- loss : 0.176093
# 3080 -- loss : 0.197216
# 3090 -- loss : -0.062534
# 3100 -- loss : -0.037111
# 3110 -- loss : -0.047571
# 3120 -- loss : 0.125552
# 3130 -- loss : 0.135561
# 3140 -- loss : -0.106566
# 3150 -- loss : -0.128146
# 3160 -- loss : -0.106585
# 3170 -- loss : -0.016291
# 3180 -- loss : -0.013041
# 3190 -- loss : 0.002440
# 3200 -- loss : -0.052537
# 3210 -- loss : -0.012441
# 3220 -- loss : -0.257021
# 3230 -- loss : -0.001833
# 3240 -- loss : 0.016265
# 3250 -- loss : 0.113327
# 3260 -- loss : 0.097575
# 3270 -- loss : 0.002159
# 3280 -- loss : 0.130863
# 3290 -- loss : -0.045355
# 3300 -- loss : -0.118118
# 3310 -- loss : -0.101738
# 3320 -- loss : -0.066612
# 3330 -- loss : -0.049037
# 3340 -- loss : 0.034222
# 3350 -- loss : -0.262366
# 3360 -- loss : 0.080604
# 3370 -- loss : 0.056790
# 3380 -- loss : 0.041077
# 3390 -- loss : -0.340427
# 3530 -- loss : 0.064895
# 3540 -- loss : -0.126007
# 3550 -- loss : -0.203645
# 3560 -- loss : -0.003264
# 3570 -- loss : 0.125711
# 3580 -- loss : 0.076588
# 3590 -- loss : 0.188323
# 3600 -- loss : -0.001219
# 3610 -- loss : -0.137018
# 3620 -- loss : -0.034342
# 3630 -- loss : -0.104081
# 3640 -- loss : 0.098478
# 3650 -- loss : 0.063404
# 3660 -- loss : 0.031273
# 3670 -- loss : -0.024244
# 3680 -- loss : -0.070891
# 3690 -- loss : 0.076088
# 3700 -- loss : 0.325284
# 3710 -- loss : 0.110436
# 3720 -- loss : -0.062959
# 3730 -- loss : -0.207155
# 3740 -- loss : -0.044169
# 3750 -- loss : 0.060560
# 3760 -- loss : 0.077960
# 3770 -- loss : -0.046222
# 3780 -- loss : -0.020637
# 3790 -- loss : 0.081591
# 3800 -- loss : -0.057625
# 3810 -- loss : -0.100486
# 3820 -- loss : -0.057335
# 3830 -- loss : -0.130892
# 3840 -- loss : 0.031651
# 3850 -- loss : 0.124767
# 3860 -- loss : 0.152538
# 3870 -- loss : -0.054132
# 3880 -- loss : 0.011968
# 3890 -- loss : -0.087583
# 3900 -- loss : -0.009642
# 3910 -- loss : -0.053307
# 3920 -- loss : 0.117431
# 3930 -- loss : -0.214402
# 3940 -- loss : 0.070357
# 3950 -- loss : -0.041993
# 3960 -- loss : 0.006293
# 3970 -- loss : 0.045484
# 3980 -- loss : 0.034044
# 3990 -- loss : 0.211127
# 4000 -- loss : 0.163984
# 4010 -- loss : -0.030586
# 4020 -- loss : -0.047565
# 4030 -- loss : 0.201310
# 4040 -- loss : 0.142625
# 4050 -- loss : 0.078558
# 4060 -- loss : -0.176793
# 4070 -- loss : -0.077779
# 4080 -- loss : -0.200883
# 4090 -- loss : 0.007220
# 4100 -- loss : -0.183335
# 4110 -- loss : -0.015036
# 4120 -- loss : -0.023961
# 4130 -- loss : 0.020293
# 4140 -- loss : -0.015518
# 4150 -- loss : 0.015544
# 4160 -- loss : -0.101429
# 4170 -- loss : -0.000950
# 4180 -- loss : 0.087367
# 4190 -- loss : -0.093638
# 4200 -- loss : -0.105975
# 4210 -- loss : -0.171165
# 4220 -- loss : -0.002422
# 4230 -- loss : 0.095601
# 4240 -- loss : -0.110150
# 4250 -- loss : -0.081988
# 4260 -- loss : 0.013995
# 4270 -- loss : -0.038091
# 4280 -- loss : -0.074816
# 4290 -- loss : 0.137993
# 4300 -- loss : 0.024259
# 4310 -- loss : 0.026419
# 4320 -- loss : -0.029126
# 4330 -- loss : 0.133478
# 4340 -- loss : -0.014845
# 4350 -- loss : -0.091656
# 4360 -- loss : 0.003710
# 4370 -- loss : 0.205656
# 4380 -- loss : -0.065946
# 4390 -- loss : -0.006722
# 4400 -- loss : 0.070313
# 4410 -- loss : 0.125460
# 4420 -- loss : 0.055861
# 4430 -- loss : 0.006885
# 4440 -- loss : 0.046849
# 4450 -- loss : 0.089459
# 4460 -- loss : -0.062495
# 4470 -- loss : -0.004885
# 4480 -- loss : -0.081142
# 4490 -- loss : 0.106554
# 4500 -- loss : 0.092122
# 4510 -- loss : 0.054512
# 4520 -- loss : -0.138616
# 4530 -- loss : -0.028944
# 4540 -- loss : 0.201939
# 4550 -- loss : 0.073623
# 4560 -- loss : 0.141867
# 4570 -- loss : 0.119814
# 4580 -- loss : -0.016361
# 4590 -- loss : 0.165871
# 4600 -- loss : 0.058814
# 4610 -- loss : 0.214645
# 4620 -- loss : -0.133385
# 4630 -- loss : 0.107297
# 4640 -- loss : 0.106826
# 4650 -- loss : 0.099516
# 4660 -- loss : 0.102206
# 4670 -- loss : -0.037885
# 4680 -- loss : -0.160979
# 4690 -- loss : 0.030678
# 4700 -- loss : 0.293824
# 4710 -- loss : 0.283220
# 4720 -- loss : -0.062474
# 4730 -- loss : 0.000096
# 4740 -- loss : 0.143461
# 4750 -- loss : 0.074947
# 4760 -- loss : -0.160856
# 4770 -- loss : 0.079769
# 4780 -- loss : 0.094448
# 4790 -- loss : -0.040620
# 4800 -- loss : -0.130016
# 4810 -- loss : 0.112072
# 4820 -- loss : -0.010893
# 4830 -- loss : 0.041357
# 4840 -- loss : -0.037519
# 4850 -- loss : -0.120381
# 4860 -- loss : -0.036123
# 4870 -- loss : -0.033195
# 4880 -- loss : -0.079122
# 4890 -- loss : 0.025730
# 4900 -- loss : -0.184565
# 4910 -- loss : -0.074126
# 4920 -- loss : 0.098929
# 4930 -- loss : -0.073813
# 4940 -- loss : -0.104299
# 4950 -- loss : -0.042033
# 4960 -- loss : -0.246795
# 4970 -- loss : -0.028286
# 4980 -- loss : 0.080421
# 4990 -- loss : -0.060667
# 5000 -- loss : -0.171430
# 5010 -- loss : -0.087690
# 5020 -- loss : 0.245944
# 5030 -- loss : -0.040534
# 5040 -- loss : 0.007359
# 5050 -- loss : -0.037829
# 5060 -- loss : -0.092389
# 5070 -- loss : -0.051445
# 5080 -- loss : 0.067045
# 5090 -- loss : 0.037587
# 5100 -- loss : -0.127670
# 5110 -- loss : 0.038405
# 5120 -- loss : -0.142548
# 5130 -- loss : -0.035034
# 5140 -- loss : -0.052410
# 5150 -- loss : -0.101632
# 5160 -- loss : 0.011030
# 5170 -- loss : -0.040619
# 5180 -- loss : -0.014843
# 5190 -- loss : -0.031439
# 5200 -- loss : -0.060133
# 5210 -- loss : -0.055718
# 5220 -- loss : -0.011555
# 5230 -- loss : 0.148914
# 5240 -- loss : -0.169245
# 5250 -- loss : 0.065531
# 5260 -- loss : 0.137553
# 5270 -- loss : 0.028197
# 5280 -- loss : 0.076605
# 5290 -- loss : 0.037282
# 5300 -- loss : -0.078769
# 5310 -- loss : -0.088324
# 5320 -- loss : 0.074305
# 5330 -- loss : -0.051077
# 5340 -- loss : 0.056054
# 5350 -- loss : 0.042618
# 5360 -- loss : -0.066317
# 5370 -- loss : 0.149406
# 5380 -- loss : 0.178940
# 5390 -- loss : -0.040915
# 5400 -- loss : 0.100599
# 5410 -- loss : -0.005061
# 5420 -- loss : -0.128178
# 5430 -- loss : -0.128687
# 5440 -- loss : -0.173436
# 5450 -- loss : -0.004705
# 5460 -- loss : -0.132830
# 5470 -- loss : 0.061481
# 5480 -- loss : -0.195303
# 5490 -- loss : 0.089384
# 5500 -- loss : 0.161114
# 5510 -- loss : -0.181598
# 5520 -- loss : -0.071495
# 5530 -- loss : -0.162790
# 5540 -- loss : 0.004784
# 5550 -- loss : 0.027864
# 5560 -- loss : -0.024839
# 5570 -- loss : -0.077150
# 5580 -- loss : -0.136888
# 5590 -- loss : -0.208137
# 5600 -- loss : -0.008720
# 5610 -- loss : -0.079557
# 5620 -- loss : 0.027138
# 5630 -- loss : -0.097338
# 5640 -- loss : 0.010143
# 5650 -- loss : 0.044091
# 5660 -- loss : -0.064132
# 5670 -- loss : 0.073365
# 5680 -- loss : -0.061579
# 5690 -- loss : 0.142510
# 5700 -- loss : 0.150871
# 5710 -- loss : 0.086746
# 5720 -- loss : -0.188298
# 5730 -- loss : -0.066743
# 5740 -- loss : -0.094172
# 5750 -- loss : 0.127755
# 5760 -- loss : -0.038414
# 5770 -- loss : -0.189603
# 5780 -- loss : -0.150187
# 5790 -- loss : 0.158079
# 5800 -- loss : -0.091043
# 5810 -- loss : -0.221012
# 5820 -- loss : 0.036956
# 5830 -- loss : -0.003825
# 5840 -- loss : -0.138275
# 5850 -- loss : 0.125736
# 5860 -- loss : -0.071784
# 5870 -- loss : 0.118684
# 5880 -- loss : 0.021773
# 5890 -- loss : -0.050466
# 5900 -- loss : 0.099092
# 5910 -- loss : 0.095469
# 5920 -- loss : 0.009059
# 5930 -- loss : -0.178723
# 5940 -- loss : -0.016056
# 5950 -- loss : 0.163967
# 5960 -- loss : -0.230355
# 5970 -- loss : 0.090123
# 5980 -- loss : 0.040047
# 5990 -- loss : 0.083571
# 6000 -- loss : -0.116526
# 6010 -- loss : -0.109955
# 6020 -- loss : -0.038204
# 6030 -- loss : -0.140845
# 6040 -- loss : 0.169979
# 6050 -- loss : -0.028445
# 6060 -- loss : 0.000586
# 6070 -- loss : 0.021210
# 6080 -- loss : 0.047774
# 6090 -- loss : -0.187155
# 6100 -- loss : 0.035125
# 6110 -- loss : -0.183096
# 6120 -- loss : -0.104671
# 6130 -- loss : 0.045225
# 6140 -- loss : -0.095020
# 6150 -- loss : 0.111138
# 6160 -- loss : -0.010098
# 6170 -- loss : -0.186709
# 6180 -- loss : -0.024294
# 6190 -- loss : -0.202136
# 6200 -- loss : 0.027445
# 6210 -- loss : -0.047655
# 6220 -- loss : 0.076748
# 6230 -- loss : 0.008113
# 6240 -- loss : 0.060367
# 6250 -- loss : -0.028682
# 6260 -- loss : -0.048185
# 6270 -- loss : -0.028543
# 6280 -- loss : 0.018912
# 6290 -- loss : -0.030414
# 6300 -- loss : -0.178802
# 6310 -- loss : -0.093833
# 6320 -- loss : 0.116258
# 6330 -- loss : -0.015547
# 6340 -- loss : 0.125872
# 6350 -- loss : 0.096519
# 6360 -- loss : 0.085588
# 6370 -- loss : -0.191368
# 6380 -- loss : -0.097845
# 6390 -- loss : 0.145547
# 6400 -- loss : 0.201069
# 6410 -- loss : -0.153859
# 6420 -- loss : 0.026131
# 6430 -- loss : 0.109503
# 6440 -- loss : -0.085084
# 6450 -- loss : 0.005679
# 6460 -- loss : -0.053003
# 6470 -- loss : 0.000563
# 6480 -- loss : -0.054990
# 6490 -- loss : 0.007270
# 6500 -- loss : -0.161026
# 6510 -- loss : 0.071216
# 6520 -- loss : -0.017174
# 6530 -- loss : -0.106210
# 6540 -- loss : 0.108832
# 6550 -- loss : 0.032074
# 6560 -- loss : 0.248992
# 6570 -- loss : -0.091548
# 6580 -- loss : 0.259976
# 6590 -- loss : 0.066271
# 6600 -- loss : 0.111284
# 6610 -- loss : 0.031722
# 6620 -- loss : -0.072928
# 6630 -- loss : -0.064281
# 6640 -- loss : -0.069929
# 6650 -- loss : -0.022462
# 6660 -- loss : -0.086059
# 6670 -- loss : 0.047964
# 6680 -- loss : 0.091302
# 6690 -- loss : -0.073779
# 6700 -- loss : 0.254399
# 6710 -- loss : -0.225694
# 6720 -- loss : 0.238087
# 6730 -- loss : 0.053645
# 6740 -- loss : 0.152994
# 6750 -- loss : 0.128273
# 6760 -- loss : -0.029143
# 6770 -- loss : 0.264379
# 6780 -- loss : 0.019380
# 6790 -- loss : 0.235562
# 6800 -- loss : -0.035882
# 6810 -- loss : 0.028862
# 6820 -- loss : -0.090182
# 6830 -- loss : 0.138935
# 6840 -- loss : 0.169745
# 6850 -- loss : -0.046585
# 6860 -- loss : -0.101065
# 6870 -- loss : -0.047871
# 6880 -- loss : 0.110393
# 6890 -- loss : -0.036820
# 6900 -- loss : -0.054251
# 6910 -- loss : -0.097712
# 6920 -- loss : -0.084747
# 6930 -- loss : -0.087823
# 6940 -- loss : 0.093604
# 6950 -- loss : 0.033607
# 6960 -- loss : -0.050596
# 6970 -- loss : 0.001351
# 6980 -- loss : 0.064767
# 6990 -- loss : 0.073819
# 7000 -- loss : 0.026678
# 7010 -- loss : 0.022405
# 7020 -- loss : -0.002636
# 7030 -- loss : 0.104512
# 7040 -- loss : 0.054131
# 7050 -- loss : -0.086407
# 7060 -- loss : 0.058954
# 7070 -- loss : 0.063073
# 7080 -- loss : -0.214087
# 7090 -- loss : 0.011266
# 7100 -- loss : -0.085272
# 7110 -- loss : 0.093381
# 7120 -- loss : -0.166154
# 7130 -- loss : -0.003273
# 7140 -- loss : 0.147302
# 7150 -- loss : 0.080976
# 7160 -- loss : 0.129644
# 7170 -- loss : -0.143807
# 7180 -- loss : 0.132270
# 7190 -- loss : -0.027165
# 7200 -- loss : -0.160668
# 7210 -- loss : 0.052165
# 7220 -- loss : 0.184456
# 7230 -- loss : 0.037702
# 7240 -- loss : 0.027966
# 7250 -- loss : -0.018284
# 7260 -- loss : -0.042609
# 7270 -- loss : 0.104054
# 7280 -- loss : -0.001689
# 7290 -- loss : -0.027655
# 7300 -- loss : -0.026697
# 7310 -- loss : 0.078242
# 7320 -- loss : 0.042496
# 7330 -- loss : -0.023619
# 7340 -- loss : 0.080005
# 7350 -- loss : -0.044069
# 7360 -- loss : -0.185640
# 7370 -- loss : 0.184572
# 7380 -- loss : 0.065310
# 7390 -- loss : -0.015366
# 7400 -- loss : 0.105140
# 7410 -- loss : 0.084033
# 7420 -- loss : -0.003637
# 7430 -- loss : -0.158319
# 7440 -- loss : 0.093280
# 7450 -- loss : 0.105174
# 7460 -- loss : 0.062223
# 7470 -- loss : -0.004828
# 7480 -- loss : 0.089850
# 7490 -- loss : 0.023222
# 7500 -- loss : -0.074869
# 7510 -- loss : 0.164583
# 7520 -- loss : -0.047481
# 7530 -- loss : -0.037971
# 7540 -- loss : -0.188084
# 7550 -- loss : -0.147497
# 7560 -- loss : -0.065406
# 7570 -- loss : 0.112200
# 7580 -- loss : -0.139302
# 7590 -- loss : -0.137728
# 7600 -- loss : -0.017281
# 7610 -- loss : -0.025970
# 7620 -- loss : -0.075630
# 7630 -- loss : 0.012628
# 7640 -- loss : -0.152688
# 7650 -- loss : 0.065088
# 7660 -- loss : 0.091544
# 7670 -- loss : -0.037157
# 7680 -- loss : -0.082065
# 7690 -- loss : 0.004117
# 7700 -- loss : 0.153081
# 7710 -- loss : 0.049075
# 7720 -- loss : 0.025621
# 7730 -- loss : 0.012177
# 7740 -- loss : -0.111213
# 7750 -- loss : 0.128410
# 7760 -- loss : -0.000262
# 7770 -- loss : 0.008825
# 7780 -- loss : 0.010557
# 7790 -- loss : -0.036170
# 7800 -- loss : -0.091570
# 7810 -- loss : 0.054125
# 7820 -- loss : 0.132727
# 7830 -- loss : -0.034326
# 7840 -- loss : -0.057174
# 7850 -- loss : 0.006203
# 7860 -- loss : -0.006324
# 7870 -- loss : -0.055272
# 7880 -- loss : -0.051536
# 7890 -- loss : 0.021451
# 7900 -- loss : -0.111926
# 7910 -- loss : 0.021365
# 7920 -- loss : 0.054469
# 7930 -- loss : -0.007079
# 7940 -- loss : 0.006915
# 7950 -- loss : -0.202495
# 7960 -- loss : -0.023546
# 7970 -- loss : 0.108504
# 7980 -- loss : 0.029858
# 7990 -- loss : -0.096797
# 8000 -- loss : -0.095435
# 8010 -- loss : 0.072423
# 8020 -- loss : -0.165353
# 8030 -- loss : -0.089311
# 8040 -- loss : 0.029744
# 8050 -- loss : 0.135976
# 8060 -- loss : 0.027687
# 8070 -- loss : -0.071639
# 8080 -- loss : 0.009192
# 8090 -- loss : 0.192909
# 8100 -- loss : -0.137020
# 8110 -- loss : 0.047150
# 8120 -- loss : 0.047798
# 8130 -- loss : 0.218325
# 8140 -- loss : 0.008960
# 8150 -- loss : -0.049699
# 8160 -- loss : -0.030348
# 8170 -- loss : 0.019789
# 8180 -- loss : -0.032712
# 8190 -- loss : 0.056414
# 8200 -- loss : 0.047148
# 8210 -- loss : 0.010996
# 8220 -- loss : -0.060266
# 8230 -- loss : 0.092752
# 8240 -- loss : -0.107626
# 8250 -- loss : 0.033737
# 8260 -- loss : 0.029747
# 8270 -- loss : -0.195085
# 8280 -- loss : 0.109928
# 8290 -- loss : 0.008102
# 8300 -- loss : 0.001885
# 8310 -- loss : -0.032115
# 8320 -- loss : 0.036174
# 8330 -- loss : 0.072495
# 8340 -- loss : 0.022515
# 8350 -- loss : 0.060928
# 8360 -- loss : -0.194467
# 8370 -- loss : -0.044383
# 8380 -- loss : -0.123295
# 8390 -- loss : 0.061325
# 8400 -- loss : -0.026428
# 8410 -- loss : 0.033387
# 8420 -- loss : -0.131363
# 8430 -- loss : 0.017358
# 8440 -- loss : 0.007052
# 8450 -- loss : -0.052946
# 8460 -- loss : -0.053818
# 8470 -- loss : 0.013821
# 8480 -- loss : 0.015676
# 8490 -- loss : 0.197212
# 8500 -- loss : 0.114974
# 8510 -- loss : 0.017723
# 8520 -- loss : 0.006366
# 8530 -- loss : -0.053734
# 8540 -- loss : -0.040736
# 8550 -- loss : 0.077710
# 8560 -- loss : 0.075153
# 8570 -- loss : 0.109305
# 8580 -- loss : -0.025585
# 8590 -- loss : 0.000272
# 8600 -- loss : 0.016830
# 8610 -- loss : 0.050747
# 8620 -- loss : 0.042656
# 8630 -- loss : -0.042294
# 8640 -- loss : 0.146479
# 8650 -- loss : 0.229571
# 8660 -- loss : -0.006425
# 8670 -- loss : 0.193830
# 8680 -- loss : -0.067586
# 8690 -- loss : 0.155496
# 8700 -- loss : -0.032131
# 8710 -- loss : -0.036951
# 8720 -- loss : -0.181162
# 8730 -- loss : 0.207517
# 8740 -- loss : 0.056013
# 8750 -- loss : 0.014864
# 8760 -- loss : -0.108394
# 8770 -- loss : -0.009365
# 8780 -- loss : 0.027545
# 8790 -- loss : -0.128056
# 8800 -- loss : 0.065876
# 8810 -- loss : 0.110884
# 8820 -- loss : -0.159672
# 8830 -- loss : -0.063793
# 8840 -- loss : 0.003386
# 8850 -- loss : -0.078937
# 8860 -- loss : -0.021857
# 8870 -- loss : -0.099771
# 8880 -- loss : 0.078556
# 8890 -- loss : -0.059760
# 8900 -- loss : -0.170374
# 8910 -- loss : 0.031774
# 8920 -- loss : -0.087709
# 8930 -- loss : 0.127116
# 8940 -- loss : 0.022405
# 8950 -- loss : -0.042853
# 8960 -- loss : -0.031085
# 8970 -- loss : 0.126449
# 8980 -- loss : 0.079872
# 8990 -- loss : 0.025801
# 9000 -- loss : 0.001898
# 9010 -- loss : 0.203842
# 9020 -- loss : 0.160605
# 9030 -- loss : 0.053561
# 9040 -- loss : 0.105396
# 9050 -- loss : -0.026171
# 9060 -- loss : 0.095859
# 9070 -- loss : -0.013300
# 9080 -- loss : -0.160450
# 9090 -- loss : 0.055459
# 9100 -- loss : 0.024343
# 9110 -- loss : 0.051080
# 9120 -- loss : 0.033500
# 9130 -- loss : -0.014953
# 9140 -- loss : -0.129077
# 9150 -- loss : -0.085937
# 9160 -- loss : -0.002819
# 9170 -- loss : -0.016301
# 9180 -- loss : 0.042386
# 9190 -- loss : 0.077510
# 9200 -- loss : 0.163116
# 9210 -- loss : -0.149898
# 9220 -- loss : -0.115137
# 9230 -- loss : -0.005366
# 9240 -- loss : -0.088273
# 9250 -- loss : -0.034409
# 9260 -- loss : 0.170597
# 9270 -- loss : -0.103325
# 9280 -- loss : 0.115510
# 9290 -- loss : 0.031293
# 9300 -- loss : 0.003048
# 9310 -- loss : 0.047857
# 9320 -- loss : -0.118699
# 9330 -- loss : 0.187262
# 9340 -- loss : -0.092720
# 9350 -- loss : 0.089702
# 9360 -- loss : 0.024245
# 9370 -- loss : 0.089468
# 9380 -- loss : 0.047123
# 9390 -- loss : 0.023871
# 9400 -- loss : 0.159425
# 9410 -- loss : -0.011524
# 9420 -- loss : -0.043387
# 9430 -- loss : -0.065257
# 9440 -- loss : -0.040084
# 9450 -- loss : 0.135314
# 9460 -- loss : 0.128964
# 9470 -- loss : -0.031021
# 9480 -- loss : 0.137017
# 9490 -- loss : 0.195486
# 9500 -- loss : -0.030577
# 9510 -- loss : 0.073220
# 9520 -- loss : -0.094431
# 9530 -- loss : -0.011919
# 9540 -- loss : 0.146048
# 9550 -- loss : -0.034186
# 9560 -- loss : 0.072711
# 9570 -- loss : 0.037640
# 9580 -- loss : -0.050323
# 9590 -- loss : 0.142990
# 9600 -- loss : 0.045312
# 9610 -- loss : -0.144535
# 9620 -- loss : 0.107208
# 9630 -- loss : 0.005711
# 9640 -- loss : 0.078627
# 9650 -- loss : -0.062966
# 9660 -- loss : 0.126453
# 9670 -- loss : -0.061576
# 9680 -- loss : -0.068110
# 9690 -- loss : 0.035742
# 9700 -- loss : -0.065847
# 9710 -- loss : 0.057522
# 9720 -- loss : -0.223590
# 9730 -- loss : 0.117196
# 9740 -- loss : 0.238817
# 9750 -- loss : 0.070656
# 9760 -- loss : -0.008204
# 9770 -- loss : 0.004076
# 9780 -- loss : 0.051668
# 9790 -- loss : -0.105333
# 9800 -- loss : -0.016237
# 9810 -- loss : -0.006010
# 9820 -- loss : 0.081862
# 9830 -- loss : 0.224922
# 9840 -- loss : 0.083334
# 9850 -- loss : 0.001164
# 9860 -- loss : -0.165911
# 9870 -- loss : 0.017593
# 9880 -- loss : -0.028249
# 9890 -- loss : 0.160219
# 9900 -- loss : 0.117691
# 9910 -- loss : 0.031699
# 9920 -- loss : 0.041208
# 9930 -- loss : 0.144894
# 9940 -- loss : 0.051856
# 9950 -- loss : 0.077263
# 9960 -- loss : 0.134129
# 9970 -- loss : 0.212134
# 9980 -- loss : 0.001668
# 9990 -- loss : -0.001361
